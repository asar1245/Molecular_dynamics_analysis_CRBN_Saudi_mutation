# %% [markdown]
# # Importing libraries

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import ticker
plt.style.use('seaborn')

# %% [markdown]
# # Convergence of the thermodynamical parameters

# %% [markdown]
# ## Temperature

# %%
temp_gmx_WT_c391r_419x =pd.read_csv('../Data/temperature_WT_C391R_419X.csv', index_col= 'Time (ns)')
temp_gmx_WT_c391r_419x
# Out:
#                 R1_WT       R2_WT       R3_WT      AVG_WT    R1_C391R  \
# Time (ns)
# 0.000000   307.012054  307.928589  311.306702  308.749115  310.577942
# 0.002000   309.490875  309.594208  309.276123  309.453735  311.148346
# 0.004000   310.226227  308.952423  308.446198  309.208283  310.608826
# 0.006000   309.735229  311.349121  308.104584  309.729645  305.662689
# 0.008000   312.776154  310.260986  311.423370  311.486837  309.466125
# ...               ...         ...         ...         ...         ...
# 49.992001  308.492188  308.444611  309.913940  308.950246  309.605225
# 49.994003  307.556793  312.313507  309.796448  309.888916  309.164398
# 49.996002  309.984772  310.039551  312.060699  310.695007  310.576447
# 49.998001  309.862885  309.221466  312.917267  310.667206  309.160431
# 50.000004  313.007629  308.090698  311.303558  310.800628  309.891602
#
#              R2_C391R    R3_C391R   AVG_C391R     R1_419X     R2_419X  \
# Time (ns)
# ...

# %%
fig1, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
temp_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Temperatura (K)', title = 'WT')
ax1.set_ylim([300, 320])
ax1.set_xlim([0, 50])
temp_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '', title = 'C391R')
ax2.set_ylim([300, 320])
ax2.set_xlim([0, 50])
temp_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '', title = '419X')
ax3.set_ylim([300, 320])
ax3.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
fig2, ax1 = plt.subplots(figsize=(12, 6))
temp_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(ylabel = 'Temperatura (K)', xlabel = '')
ax1.set_ylim([305, 315])
ax1.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
mean_m_wt_temp = temp_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_temp = temp_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_temp = temp_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_temp = temp_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_temp = temp_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_temp = temp_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_temp = std_wt_temp.mean()
meand_std_c391r_temp = std_c391r_temp.mean()
meand_std_419x_temp = std_419x_temp.mean()
print("WT Avergae Temperature: ", mean_m_wt_temp, "±", meand_std_wt_temp)
print("C391R Avergae Temperature: ", mean_m_c391r_temp, "±", meand_std_c391r_temp)
print("419X Avergae Temperature: ", mean_m_419X_temp, "±", meand_std_419x_temp)
# Out:
# WT Avergae Temperature:  309.9873904754743 ± 1.3027421294572727
# C391R Avergae Temperature:  309.9784700123595 ± 1.2980146084468092
# 419X Avergae Temperature:  309.98009670405185 ± 1.2975550521683203

# %% [markdown]
# ## Pressure

# %%
pres_gmx_WT_c391r_419x =pd.read_csv('../Data/pressure_WT_C391R_419X.csv', index_col= 'Time (ns)')
pres_gmx_WT_c391r_419x
# Out:
#                 R1_WT       R2_WT       R3_WT      AVG_WT    R1_C391R  \
# Time (ns)
# 0.000000    25.062225  172.166565   63.179428   86.802739   49.942551
# 0.002000   105.738342 -248.510239  192.148453   16.458852  -89.947067
# 0.004000   -12.777817 -105.989426  250.161118   43.797958   18.606720
# 0.006000  -239.670441   27.043701  126.896744  -28.576665   16.261475
# 0.008000    10.758530   11.756851  -61.467300  -12.983973   -3.834946
# ...               ...         ...         ...         ...         ...
# 49.992001  -23.810181 -180.292633   -9.920135  -71.340983  167.229294
# 49.994003 -195.294922  167.335373 -106.413414  -44.790988 -157.398911
# 49.996002  -59.297043  -60.617477   84.088089  -11.942144   32.098526
# 49.998001 -178.346359 -103.959274 -149.327545 -143.877726 -105.031113
# 50.000004  191.176575  -73.012726   37.154755   51.772868  -77.314423
#
#              R2_C391R    R3_C391R   AVG_C391R     R1_419X     R2_419X  \
# Time (ns)
# ...

# %%
fig3, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
pres_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Presión (bar)') #, title = 'WT')
ax1.set_ylim([-700, 700])
ax1.set_xlim([0, 50])
pres_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '')#, ylabel = 'Presión (bar)')#, title = 'C391R')
ax2.set_ylim([-700, 700])
ax2.set_xlim([0, 50])
ax2.legend(loc='upper right')
pres_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '')#, ylabel = 'Presión (bar)')#, title = '419X')
ax3.set_ylim([-700, 700])
ax3.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
fig4, ax1 = plt.subplots(figsize=(12, 6))
pres_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'Presión (bar)')
ax1.set_ylim([-500, 500])
ax1.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
mean_m_wt_pr = pres_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_pr = pres_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_pr = pres_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_pr = pres_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_pr = pres_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_pr = pres_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_pr = std_wt_pr.mean()
meand_std_c391r_pr = std_c391r_pr.mean()
meand_std_419x_pr = std_419x_pr.mean()
print("WT Avergae Pressure: ", mean_m_wt_pr, "±", meand_std_wt_pr)
print("C391R Avergae Pressure: ", mean_m_c391r_pr, "±", meand_std_c391r_pr)
print("419X Avergae Pressure: ", mean_m_419X_pr, "±", meand_std_419x_pr)
# Out:
# WT Avergae Pressure:  0.8245493728650863 ± 103.57047496122699
# C391R Avergae Pressure:  0.7595575142860953 ± 103.5826994411865
# 419X Avergae Pressure:  0.964264088623122 ± 102.82791557567832

# %% [markdown]
# ## Volume

# %%
vol_gmx_WT_c391r_419x =pd.read_csv('../Data/volume_WT_C391R_419X.csv', index_col= 'Time (ns)')
vol_gmx_WT_c391r_419x
# Out:
#                 R1_WT       R2_WT       R3_WT      AVG_WT    R1_C391R  \
# Time (ns)
# 0.000000   562.308777  561.910461  564.928162  563.049133  567.005005
# 0.002000   566.748779  565.513062  566.174072  566.145304  566.657654
# 0.004000   563.298462  564.674561  564.009521  563.994181  565.552002
# 0.006000   564.184204  563.977234  564.888123  564.349854  564.443176
# 0.008000   565.981567  564.553589  565.689636  565.408264  566.192688
# ...               ...         ...         ...         ...         ...
# 49.992001  564.416565  565.688599  567.326294  565.810486  565.184021
# 49.994003  566.578430  564.226135  565.338318  565.380961  564.994141
# 49.996002  564.072144  563.727234  563.392395  563.730591  562.954407
# 49.998001  564.333069  567.013733  566.990234  566.112345  566.807190
# 50.000004  564.633789  566.457214  563.889526  564.993510  564.821289
#
#              R2_C391R    R3_C391R   AVG_C391R     R1_419X     R2_419X  \
# Time (ns)
# ...

# %%
fig5, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
vol_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Volumen (nm^3)')#, title = 'WT')
ax1.set_ylim([558, 572])
ax1.set_xlim([0, 50])
vol_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '')#, ylabel = 'Volumen (nm^3)')#, title = 'C391R')
ax2.set_ylim([558, 572])
ax2.set_xlim([0, 50])
vol_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '')#, ylabel = 'Volumen (nm^3)')#, title = '419X')
ax3.set_ylim([558, 572])
ax3.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
fig6, ax1 = plt.subplots(figsize=(12, 6))
vol_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'Volumen (nm^3)')
ax1.set_ylim([560, 570])
ax1.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
mean_m_wt_vl = vol_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_vl = vol_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_vl = vol_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_vl = vol_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_vl = vol_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_vl = vol_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_vl = std_wt_vl.mean()
meand_std_c391r_vl = std_c391r_vl.mean()
meand_std_419x_vl = std_419x_vl.mean()
print("WT Avergae Volumen: ", mean_m_wt_vl, "±", meand_std_wt_vl)
print("C391R Avergae Volumen: ", mean_m_c391r_vl, "±", meand_std_c391r_vl)
print("419X Avergae Volumen: ", mean_m_419X_vl, "±", meand_std_419x_vl)
# Out:
# WT Avergae Volumen:  564.7476235145795 ± 1.0208224080481532
# C391R Avergae Volumen:  564.8481317525033 ± 1.0216072229376651
# 419X Avergae Volumen:  564.6506893299869 ± 1.0235525162413952

# %% [markdown]
# ## Potential energy

# %%
pot_gmx_WT_c391r_419x =pd.read_csv('../Data/poten_WT_C391R_419X.csv', index_col= 'Time (ns)')
pot_gmx_WT_c391r_419x
# Out:
#                  R1_WT        R2_WT        R3_WT         AVG_WT     R1_C391R  \
# Time (ns)
# 0.000000  -704962.3750 -704924.0000 -701770.1250 -703885.500000 -703283.8750
# 0.002000  -700559.5625 -705287.6875 -703300.3750 -703049.208333 -702448.5625
# 0.004000  -704198.1875 -703761.2500 -701774.5625 -703244.666667 -702570.4375
# 0.006000  -705089.0000 -701867.3125 -704280.7500 -703745.687500 -703604.5625
# 0.008000  -701339.3750 -701795.7500 -704978.5625 -702704.562500 -701763.2500
# ...                ...          ...          ...            ...          ...
# 49.992001 -702900.1250 -701866.9375 -701628.1875 -702131.750000 -703324.2500
# 49.994003 -704517.3125 -703278.6250 -701632.2500 -703142.729167 -704391.9375
# 49.996002 -702971.3750 -704319.3750 -704103.8750 -703798.208333 -705141.1875
# 49.998001 -703731.9375 -702329.1250 -702850.7500 -702970.604167 -702789.7500
# 50.000004 -703496.7500 -703171.8750 -702925.2500 -703197.958333 -702807.5000
#
# ...

# %%
fig7, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
pot_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Energía potencial(kJ/mol)', title = 'WT')
ax1.set_ylim([-709000, -697000])
ax1.set_xlim([0, 50])
pot_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '', title = 'C391R')#, ylabel = 'Energía potencial (kJ/mol)')
ax2.set_ylim([-709000, -697000])
ax2.set_xlim([0, 50])
pot_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '', title = '419X')#, ylabel = 'Energía potencial (kJ/mol)')
ax3.set_ylim([-709000, -697000])
ax3.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter) 
ax2.yaxis.set_major_formatter(formatter) 
ax3.yaxis.set_major_formatter(formatter)

# %%
fig8, ax1 = plt.subplots(figsize=(12, 6))
pot_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'Energía potencial (kJ/mol)')
ax1.set_ylim([-707000, -700000])
ax1.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter)

# %%
mean_m_wt_pot = pot_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_pot = pot_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_pot = pot_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_pot = pot_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_pot = pot_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_pot = pot_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_pot = std_wt_pot.mean()
meand_std_c391r_pot = std_c391r_pot.mean()
meand_std_419x_pot = std_419x_pot.mean()
print("WT Avergae Potential Energy: ", mean_m_wt_pot, "±", meand_std_wt_pot)
print("C391R Avergae Potential Energy: ", mean_m_c391r_pot, "±", meand_std_c391r_pot)
print("419X Avergae Potential Energy: ", mean_m_419X_pot, "±", meand_std_419x_pot)
# Out:
# WT Avergae Potential Energy:  -703189.2811737531 ± 857.135727681067
# C391R Avergae Potential Energy:  -703554.4469304561 ± 858.5969601605524
# 419X Avergae Potential Energy:  -704179.6757538031 ± 858.5553082904207

# %% [markdown]
# ## Kinetic energy

# %%
kin_gmx_WT_c391r_419x =pd.read_csv('../Data/kinen_WT_C391R_419X.csv', index_col= 'Time (ns)')
kin_gmx_WT_c391r_419x
# Out:
#                    R1_WT          R2_WT          R3_WT         AVG_WT  \
# Time (ns)
# 0.000000   143329.468750  143757.359375  145334.437500  144140.421875
# 0.002000   144486.703125  144534.953125  144386.468750  144469.375000
# 0.004000   144830.015625  144235.328125  143999.000000  144354.781250
# 0.006000   144600.796875  145354.250000  143839.515625  144598.187500
# 0.008000   146020.437500  144846.250000  145388.890625  145418.526042
# ...                  ...            ...            ...            ...
# 49.992001  144020.468750  143998.250000  144684.218750  144234.312500
# 49.994003  143583.781250  145804.484375  144629.375000  144672.546875
# 49.996002  144717.281250  144742.859375  145686.437500  145048.859375
# 49.998001  144660.375000  144360.921875  146086.312500  145035.869792
# 50.000004  146128.515625  143833.031250  145332.984375  145098.177083
#
#                 R1_C391R       R2_C391R       R3_C391R      AVG_C391R  \
# Time (ns)
# ...

# %%
fig7, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
kin_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Energía cinética (kJ/mol)')#, title = 'WT')
ax1.set_ylim([141000, 149000])
ax1.set_xlim([0, 50])
kin_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '')#, ylabel = 'Energía cinética (kJ/mol)', title = 'C391R')
ax2.set_ylim([141000, 149000])
ax2.set_xlim([0, 50])
kin_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '')#, ylabel = 'Energía cinética (kJ/mol)', title = '419X')
ax3.set_ylim([141000, 149000])
ax3.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter) 
ax2.yaxis.set_major_formatter(formatter) 
ax3.yaxis.set_major_formatter(formatter)

# %%
fig8, ax1 = plt.subplots(figsize=(12, 6))
kin_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'Energía cinética (kJ/mol)')
ax1.set_ylim([142000, 147000])
ax1.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter)

# %%
mean_m_wt_kin = kin_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_kin = kin_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_kin = kin_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_kin = kin_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_kin = kin_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_kin = kin_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_kin = std_wt_kin.mean()
meand_std_c391r_kin = std_c391r_kin.mean()
meand_std_419x_kin = std_419x_kin.mean()
print("WT Avergae Kinetic Energy: ", mean_m_wt_kin, "±", meand_std_wt_kin)
print("C391R Avergae Kinetic Energy: ", mean_m_c391r_kin, "±", meand_std_c391r_kin)
print("419X Avergae Kinetic Energy: ", mean_m_419X_kin, "±", meand_std_419x_kin)
# Out:
# WT Avergae Kinetic Energy:  144718.50980877434 ± 608.1889257445225
# C391R Avergae Kinetic Energy:  144751.71610406417 ± 606.1383665424622
# 419X Avergae Kinetic Energy:  144649.38311405046 ± 605.4922551705056

# %% [markdown]
# ## Total energy

# %%
toten_gmx_WT_c391r_419x =pd.read_csv('../Data/toten_WT_C391R_419X.csv', index_col= 'Time (ns)')
toten_gmx_WT_c391r_419x
# Out:
#                  R1_WT        R2_WT        R3_WT         AVG_WT     R1_C391R  \
# Time (ns)
# 0.000000  -561632.8750 -561166.6250 -556435.6875 -559745.062500 -558252.2500
# 0.002000  -556072.8750 -560752.7500 -558913.8750 -558579.833333 -557150.5625
# 0.004000  -559368.1875 -559525.9375 -557775.5625 -558889.895833 -557524.3750
# 0.006000  -560488.1875 -556513.0625 -560441.2500 -559147.500000 -560868.1875
# 0.008000  -555318.9375 -556949.5000 -559589.6875 -557286.041667 -557250.7500
# ...                ...          ...          ...            ...          ...
# 49.992001 -558879.6250 -557868.6875 -556944.0000 -557897.437500 -558746.8750
# 49.994003 -560933.5000 -557474.1250 -557002.8750 -558470.166667 -560020.3750
# 49.996002 -558254.1250 -559576.5000 -558417.4375 -558749.354167 -560110.2500
# 49.998001 -559071.5625 -557968.1875 -556764.4375 -557934.729167 -558420.0000
# 50.000004 -557368.2500 -559338.8750 -557592.2500 -558099.791667 -558096.3750
#
# ...

# %%
fig9, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
kin_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'Energía total (kJ/mol)')#, title = 'WT')
ax1.set_ylim([141000, 149000])
ax1.set_xlim([0, 50])
kin_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = 'Tiempo (ns)')#, ylabel = 'Energía total (kJ/mol)', title = 'C391R')
ax2.set_ylim([141000, 149000])
ax2.set_xlim([0, 50])
kin_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = 'Tiempo (ns)')#, ylabel = 'Energía total (kJ/mol)', title = '419X')
ax3.set_ylim([141000, 149000])
ax3.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter) 
ax2.yaxis.set_major_formatter(formatter) 
ax3.yaxis.set_major_formatter(formatter)

# %%
fig10, ax1 = plt.subplots(figsize=(12, 6))
kin_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'Energía total (kJ/mol)')
ax1.set_ylim([142000, 147000])
ax1.set_xlim([0, 50])
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax1.yaxis.set_major_formatter(formatter)

# %%
mean_m_wt_tot = toten_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_tot = toten_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_tot = toten_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_tot = toten_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_tot = toten_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_tot = toten_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_tot = std_wt_tot.mean()
meand_std_c391r_tot = std_c391r_tot.mean()
meand_std_419x_tot = std_419x_tot.mean()
print("WT Avergae Total Energy: ", mean_m_wt_tot, "±", meand_std_wt_tot)
print("C391R Avergae Total Energy: ", mean_m_c391r_tot, "±", meand_std_c391r_tot)
print("419X Avergae Total Energy: ", mean_m_419X_tot, "±", meand_std_419x_tot)
# Out:
# WT Avergae Total Energy:  -558470.7713091476 ± 1143.3021480729133
# C391R Avergae Total Energy:  -558802.7307999347 ± 1143.1451738040146
# 419X Avergae Total Energy:  -559530.2926107955 ± 1139.4649903013944

# %% [markdown]
# # Conformational dynamics and stability

# %% [markdown]
# ## Protein radius of gration

# %%
rg_gmx_WT_c391r_419x =pd.read_csv('../Data/gyrate_radio.csv', index_col= 'Time (ns)')
rg_gmx_WT_c391r_419x
# Out:
#              R1_WT    R2_WT    R3_WT    AVG_WT  R1_C391R  R2_C391R  R3_C391R  \
# Time (ns)
# 0.000000   2.27199  2.28165  2.27526  2.276300   2.28049   2.29167   2.25150
# 0.002000   2.26788  2.28049  2.27720  2.275190   2.28591   2.28729   2.24722
# 0.004000   2.27244  2.28659  2.27781  2.278947   2.28849   2.28791   2.25875
# 0.006000   2.27229  2.29344  2.28982  2.285183   2.29578   2.29135   2.25400
# 0.008000   2.27509  2.27871  2.28877  2.280857   2.28337   2.29706   2.24634
# ...            ...      ...      ...       ...       ...       ...       ...
# 49.992001  2.30062  2.28135  2.27518  2.285717   2.26954   2.29887   2.23471
# 49.994003  2.30397  2.26773  2.28163  2.284443   2.26950   2.29613   2.23056
# 49.996002  2.31067  2.27964  2.27613  2.288813   2.27275   2.29360   2.22601
# 49.998001  2.30929  2.27477  2.27950  2.287853   2.26689   2.29583   2.23240
# 50.000004  2.30298  2.28254  2.28643  2.290650   2.26952   2.29592   2.23083
#
# ...

# %%
fig11, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rg_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'Radio de giro (nm)')#, title = 'WT')
ax1.set_xlim([0, 50])
ax1.set_ylim([2.20, 2.36])
ax1.legend(loc='upper right')
rg_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '')#, title = 'C391R',  ylabel = 'Radio de giro (nm)')
ax2.set_xlim([0, 50])
ax2.set_ylim([2.20, 2.36])
ax2.legend(loc='upper right')
rg_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '')#, title = '419X',  ylabel = 'Radio de giro (nm)')
ax3.set_xlim([0, 50])
ax3.set_ylim([2.22, 2.40])
ax3.legend(loc='upper right')

# %%
fig12, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
rg_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'Radio de giro (nm)')
ax1.set_xlim([0, 50])
ax1.set_ylim([2.22, 2.35])
ax1.legend(loc='upper right')
ax2.set(xlabel = '', ylabel = 'Función de densidad de probabilidad')
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_WT'], shade=True, label = "WT")
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_C391R'], shade=True, label = "C391R")
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_419X'], shade=True, label = "419X")

# %%
mean_m_wt_rg = rg_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_rg = rg_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_rg = rg_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_rg = rg_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_rg = rg_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_rg = rg_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_rg = std_wt_rg.mean()
meand_std_c391r_rg = std_c391r_rg.mean()
meand_std_419x_rg = std_419x_rg.mean()
print("WT Average Radius of giration complete: ", mean_m_wt_rg, "±", meand_std_wt_rg)
print("C391R Avergae Radius of giration complete: ", mean_m_c391r_rg, "±", meand_std_c391r_rg)
print("419X Avergae Radius of giration complete: ", mean_m_419X_rg, "±", meand_std_419x_rg)
# Out:
# WT Average Radius of giration complete:  2.2795687439169097 ± 0.015030440727081129
# C391R Avergae Radius of giration complete:  2.2804225030998757 ± 0.021153276118311505
# 419X Avergae Radius of giration complete:  2.299510809300961 ± 0.02005691165860311

# %%
fig31, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
temp_30ns = rg_gmx_WT_c391r_419x[['AVG_WT', 'AVG_C391R', 'AVG_419X']].iloc[10000:]
temp_30ns.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ps)', ylabel = 'Radio de giro (nm)')
ax1.set_xlim([20, 50])
ax1.set_ylim([2.24, 2.34])
ax1.legend(loc='upper right')
ax2.set(xlabel = 'Radio de giro (nm)', ylabel = 'Función de densidad de probabilidad')
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:], shade=True, label = "WT")
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:], shade=True, label = "C391R")
p1=sns.kdeplot(rg_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:], shade=True, label = "419X")

# %%
mean_m_wt_rg_20 = rg_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:].mean(0)
mean_m_c391r_rg_20 = rg_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:].mean(0)
mean_m_419X_rg_20 = rg_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:].mean(0)
std_wt_rg_20 = rg_gmx_WT_c391r_419x[['R1_WT','R2_WT', 'R3_WT']].iloc[10000:].std(1)
std_c391r_rg_20 = rg_gmx_WT_c391r_419x[['R1_C391R', 'R2_C391R', 'R3_C391R']].iloc[10000:].std(1)
std_419X_rg_20 = rg_gmx_WT_c391r_419x[["R1_419X", "R2_419X", "R3_419X"]].iloc[10000:].std(1)
meand_std_wt_rg_20 = std_wt_rg_20.mean()
meand_std_c391r_rg_20 = std_c391r_rg_20.mean()
meand_std_419X_rg_20 = std_419X_rg_20.mean()
print("WT Average Radius of giration 30ns: ", mean_m_wt_rg_20, "±", meand_std_wt_rg_20)
print("C391R Avergae Radius of giration 30ns: ", mean_m_c391r_rg_20, "±", meand_std_c391r_rg_20)
print("419X Avergae Radius of giration 30ns: ", mean_m_419X_rg_20, "±", meand_std_419X_rg_20)
# Out:
# WT Average Radius of giration 30ns:  2.279199737795258 ± 0.016946430236191367
# C391R Avergae Radius of giration 30ns:  2.2743587943026022 ± 0.026291521701925984
# 419X Avergae Radius of giration 30ns:  2.2985570081994537 ± 0.020193652286872733

# %% [markdown]
# ## Backbone RMSD

# %%
rmsd_gmx_WT_c391r_419x = pd.read_csv('../Data/rmsd_WT_C391R_419X.csv', index_col= 'Time (ns)')
rmsd_gmx_WT_c391r_419x
# Out:
#            R1_WT_ES  R2_WT_ES  R3_WT_ES  AVG_WT_ES  R1_WT_CS  R2_WT_CS  \
# Time (ns)
# 0.000000   0.000498  0.000505  0.000508   0.000504  0.164527  0.187428
# 0.002000   0.056475  0.055651  0.061938   0.058022  0.163487  0.193144
# 0.004000   0.068153  0.068095  0.076512   0.070920  0.158560  0.190247
# 0.006000   0.069630  0.071204  0.079292   0.073375  0.160408  0.184125
# 0.008000   0.076331  0.072311  0.075623   0.074755  0.158437  0.186030
# ...             ...       ...       ...        ...       ...       ...
# 49.992001  0.231880  0.315861  0.214743   0.254161  0.247912  0.314781
# 49.994003  0.228369  0.314551  0.216418   0.253113  0.241758  0.319972
# 49.996002  0.242834  0.322497  0.216727   0.260686  0.245876  0.323989
# 49.998001  0.236783  0.319017  0.215729   0.257177  0.243715  0.323530
# 50.000004  0.236509  0.318708  0.219297   0.258171  0.242303  0.322636
#
#            R3_WT_CS  AVG_WT_CS  R1_C391R_ES  R2_C391R_ES  ...  R3_C391R_CS  \
# ...

# %% [markdown]
# ### WT

# %%
fig13, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_WT_ES', 'R2_WT_ES', 'R3_WT_ES'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura equilibrada')
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_WT_CS', 'R2_WT_CS', 'R3_WT_CS'], ax = ax2)
ax2.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura de cristal')
rmsd_gmx_WT_c391r_419x.plot( y = ['AVG_WT_ES', 'AVG_WT_CS'], ax = ax3)
ax3.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSD (nm)'),
#  Text(0.5, 0, 'Tiempo (ns)'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %% [markdown]
# ### C391R

# %% [markdown]
# #### Relative to equilibrated and cristal structure, and comparison

# %%
fig14, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_C391R_ES', 'R2_C391R_ES', 'R3_C391R_ES'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura equilibrada')
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_C391R_CS', 'R2_C391R_CS', 'R3_C391R_CS'], ax = ax2)
ax2.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura de cristal')
rmsd_gmx_WT_c391r_419x.plot( y = ['AVG_C391R_ES', 'AVG_C391R_CS'], ax = ax3)
ax3.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSD (nm)'),
#  Text(0.5, 0, 'Tiempo (ns)'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %% [markdown]
# ### 419X

# %% [markdown]
# #### Relative to equilibrated structure

# %%
fig15, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_419X_ES', 'R2_419X_ES', 'R3_419X_ES'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura equilibrada')
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_419X_CS', 'R2_419X_CS', 'R3_419X_CS'], ax = ax2)
ax2.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura de cirstal')
rmsd_gmx_WT_c391r_419x.plot( y = ['AVG_419X_ES', 'AVG_419X_CS'], ax = ax3)
ax3.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSD (nm)'),
#  Text(0.5, 0, 'Tiempo (ns)'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %%
fig24, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_WT_ES', 'R2_WT_ES', 'R3_WT_ES'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'RMSD (nm)')#, title = 'WT')
ax1.set_ylim([0, 0.40])
ax1.legend(loc='upper right')
rmsd_gmx_WT_c391r_419x.plot(y = ['R1_C391R_ES', 'R2_C391R_ES', 'R3_C391R_ES'], ax = ax2)
ax2.set(xlabel = '')#, title = 'C391R'), ylabel = 'RMSD (nm)')
ax2.set_ylim([0, 0.50])
ax2.legend(loc='upper right')
rmsd_gmx_WT_c391r_419x.plot( y = ['R1_419X_ES', 'R2_419X_ES', 'R3_419X_ES'], ax = ax3)
ax3.set(xlabel = '')#, title = '419X', ylabel = 'RMSD (nm)')
ax3.legend(loc='upper right')

# %% [markdown]
# ### WT vs 391R vs 419X

# %%
fig16, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['AVG_WT_ES', 'AVG_C391R_ES', 'AVG_419X_ES'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura equilibrada')
rmsd_gmx_WT_c391r_419x.plot(y = ['AVG_WT_CS', 'AVG_C391R_CS', 'AVG_419X_CS'], ax = ax2)
Aax2.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)', title = 'Estructura de cristal')
# Out:
# [Text(0, 0.5, 'RMSD (nm)'),
#  Text(0.5, 0, 'Tiempo (ns)'),
#  Text(0.5, 1.0, 'Estructura de cristal')]

# %%
fig25, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
rmsd_gmx_WT_c391r_419x.plot(y = ['AVG_WT_ES', 'AVG_C391R_ES', 'AVG_419X_ES'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'RMSD (nm)')
ax1.set_ylim([0, 0.40])
ax1.set_xlim([0, 50])
ax1.legend(loc='upper right')
ax2.set(xlabel = '', ylabel = 'Función de densidad de probabilidad')
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_WT_ES'], shade=True, label = "WT")
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_C391R_ES'], shade=True, label = "C391R")
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_419X_ES'], shade=True, label = "419X")

# %%
mean_m_wt_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,"AVG_WT_ES"].mean(0)
mean_m_c391r_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,"AVG_C391R_ES"].mean(0)
mean_m_419X_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,"AVG_419X_ES"].mean(0)
std_wt_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,["R1_WT_ES", "R2_WT_ES", "R3_WT_ES"]].std(1)
std_c391r_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,["R1_C391R_ES", "R2_C391R_ES", "R3_C391R_ES"]].std(1)
std_419x_rmsd = rmsd_gmx_WT_c391r_419x.loc[:,["R1_419X_ES", "R2_419X_ES", "R3_419X_ES"]].std(1)
meand_std_wt_rmsd = std_wt_rmsd.mean()
meand_std_c391r_rmsd = std_c391r_rmsd.mean()
meand_std_419x_rmsd = std_419x_rmsd.mean()
print("WT Avergae RMSD complete: ", mean_m_wt_rmsd, "±", meand_std_wt_rmsd)
print("C391R Avergae RMSD complete: ", mean_m_c391r_rmsd, "±", meand_std_c391r_rmsd)
print("419X Avergae RMSD complete: ", mean_m_419X_rmsd, "±", meand_std_419x_rmsd)
# Out:
# WT Avergae RMSD complete:  0.20214513086009891 ± 0.01994838762908915
# C391R Avergae RMSD complete:  0.2380014305307788 ± 0.051913656845779886
# 419X Avergae RMSD complete:  0.2663946639134434 ± 0.033219407380866574

# %%
fig33, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
temp_30ns = rmsd_gmx_WT_c391r_419x[['AVG_WT_ES', 'AVG_C391R_ES', 'AVG_419X_ES']].iloc[10000:]
temp_30ns.plot(y = ['AVG_WT_ES', 'AVG_C391R_ES', 'AVG_419X_ES'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ns)', ylabel = 'RMSD (nm)')
ax1.set_ylim([0.10, 0.40])
ax1.set_xlim([20, 50])
ax1.legend(loc='upper right')
ax2.set(xlabel = 'RMSD (nm)', ylabel = 'Función de densidad de probabilidad')
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_WT_ES'].iloc[10000:], shade=True, label = "WT")
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_C391R_ES'].iloc[10000:], shade=True, label = "C391R")
p2=sns.kdeplot(rmsd_gmx_WT_c391r_419x['AVG_419X_ES'].iloc[10000:], shade=True, label = "419X")

# %%
mean_m_wt_rmsd_20 = rmsd_gmx_WT_c391r_419x['AVG_WT_ES'].iloc[10000:].mean(0)
mean_m_c391r_rmsd_20 = rmsd_gmx_WT_c391r_419x['AVG_C391R_ES'].iloc[10000:].mean(0)
mean_m_419X_rmsd_20 = rmsd_gmx_WT_c391r_419x['AVG_419X_ES'].iloc[10000:].mean(0)
std_wt_rmsd_20 = rmsd_gmx_WT_c391r_419x[['R1_WT_ES','R2_WT_ES', 'R3_WT_ES']].iloc[10000:].std(1)
std_c391r_rmsd_20 = rmsd_gmx_WT_c391r_419x[['R1_C391R_ES', 'R2_C391R_ES', 'R3_C391R_ES']].iloc[10000:].std(1)
std_419X_rmsd_20 = rmsd_gmx_WT_c391r_419x[["R1_419X_ES", "R2_419X_ES", "R3_419X_ES"]].iloc[10000:].std(1)
meand_std_wt_rmsd_20 = std_wt_rmsd_20.mean()
meand_std_c391r_rmsd_20 = std_c391r_rmsd_20.mean()
meand_std_419X_rmsd_20 = std_419X_rmsd_20.mean()
print("WT Average RMSD 30ns: ", mean_m_wt_rmsd_20, "±", meand_std_wt_rmsd_20)
print("C391R Avergae 30ns: ", mean_m_c391r_rmsd_20, "±", meand_std_c391r_rmsd_20)
print("419X Avergae 30ns: ", mean_m_419X_rmsd_20, "±", meand_std_419X_rmsd_20)
# Out:
# WT Average RMSD 30ns:  0.21407191613003576 ± 0.020555571150528532
# C391R Avergae 30ns:  0.2587067013910184 ± 0.055611538153504746
# 419X Avergae 30ns:  0.28346623399328935 ± 0.030341070642729444

# %% [markdown]
# ## Backbone RMSF

# %%
rmsf_gmx_WT =pd.read_csv('../Data/rmsf_WT.csv', index_col= 'Atom')
rmsf_gmx_C391R =pd.read_csv('../Data/rmsf_C391R.csv', index_col= 'Atom')
rmsf_gmx_419X =pd.read_csv('../Data/rmsf_419X.csv', index_col= 'Atom')

# %% [markdown]
# ### WT

# %%
fig17, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsf_gmx_WT.plot(y = ['R1_WT_ES', 'R2_WT_ES', 'R3_WT_ES'], ax = ax1)
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura equilibrada')
rmsf_gmx_WT.plot(y = ['R1_WT_CS', 'R2_WT_CS', 'R3_WT_CS'], ax = ax2)
ax2.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura de cristal')
rmsf_gmx_WT.plot( y = ['AVG_WT_ES', 'AVG_WT_CS'], ax = ax3)
ax3.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSF (nm)'),
#  Text(0.5, 0, 'Átomo'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %% [markdown]
# ### C391R

# %%
fig18, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsf_gmx_C391R.plot(y = ['R1_C391R_ES', 'R2_C391R_ES', 'R3_C391R_ES'], ax = ax1)
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura equilibrada')
rmsf_gmx_C391R.plot(y = ['R1_C391R_CS', 'R2_C391R_CS', 'R3_C391R_CS'], ax = ax2)
ax2.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura de cristal')
rmsf_gmx_C391R.plot( y = ['AVG_C391R_ES', 'AVG_C391R_CS'], ax = ax3)
ax3.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSF (nm)'),
#  Text(0.5, 0, 'Átomo'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %% [markdown]
# ### 419X

# %%
fig19, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsf_gmx_419X.plot(y = ['R1_419X_ES', 'R2_419X_ES', 'R3_419X_ES'], ax = ax1)
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura equilibrada')
rmsf_gmx_419X.plot(y = ['R1_419X_CS', 'R2_419X_CS', 'R3_419X_CS'], ax = ax2)
ax2.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura de cistal')
rmsf_gmx_419X.plot( y = ['AVG_419X_ES', 'AVG_419X_CS'], ax = ax3)
ax3.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Comparación promedio ES vs CS')
# Out:
# [Text(0, 0.5, 'RMSF (nm)'),
#  Text(0.5, 0, 'Átomo'),
#  Text(0.5, 1.0, 'Comparación promedio ES vs CS')]

# %%
fig26, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
rmsf_gmx_WT.plot(y = ['R1_WT_ES', 'R2_WT_ES', 'R3_WT_ES'], ax = ax1)
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'WT')
ax1.set_ylim([0, 0.6])
ax1.legend(loc='upper right')
rmsf_gmx_C391R.plot(y = ['R1_C391R_ES', 'R2_C391R_ES', 'R3_C391R_ES'], ax = ax2)
ax2.set(xlabel = 'Átomo', title = 'C391R')#, ylabel = 'RMSF (nm)',)
#ax2.set_ylim([0, 0.50])
ax2.legend(loc='upper right')
rmsf_gmx_419X.plot(y = ['R1_419X_ES', 'R2_419X_ES', 'R3_419X_ES'], ax = ax3)
ax3.set(xlabel = 'Átomo',title = '419X')#, ylabel = 'RMSF (nm)',)
ax3.legend(loc='upper right')

# %% [markdown]
# ### WT vs 391R vs 419X

# %%
fig20, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
rmsf_gmx_WT.plot(ax = ax1, y = 'AVG_WT_ES')
rmsf_gmx_C391R.plot(ax = ax1, y = 'AVG_C391R_ES')
rmsf_gmx_419X.plot(ax = ax1, y = 'AVG_419X_ES')
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura equilibrada')
rmsf_gmx_WT.plot(ax = ax2, y = 'AVG_WT_CS')
rmsf_gmx_C391R.plot(ax = ax2, y = 'AVG_C391R_CS')
rmsf_gmx_419X.plot(ax = ax2, y = 'AVG_419X_CS')
ax2.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)', title = 'Estructura de cristal')
# Out:
# [Text(0, 0.5, 'RMSF (nm)'),
#  Text(0.5, 0, 'Átomo'),
#  Text(0.5, 1.0, 'Estructura de cristal')]

# %%
fig27, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
rmsf_gmx_WT.plot(ax = ax1, y = 'AVG_WT_ES', label = "WT")
rmsf_gmx_C391R.plot(ax = ax1, y = 'AVG_C391R_ES', label = "C391R")
rmsf_gmx_419X.plot(ax = ax1, y = 'AVG_419X_ES', label = "419X")
ax1.set(xlabel = 'Átomo', ylabel = 'RMSF (nm)')
ax1.legend(loc='upper right')
ax1.set_ylim([0, 0.6])
ax1.set_xlim([0, 6150])
ax2.set(xlabel = 'RMSF (nm)', ylabel = 'Función de densidad de probabilidad')
p3=sns.kdeplot(rmsf_gmx_WT['AVG_WT_ES'], shade=True, label = "WT")
p3=sns.kdeplot(rmsf_gmx_C391R['AVG_C391R_ES'], shade=True, label = "C391R")
p3=sns.kdeplot(rmsf_gmx_419X['AVG_419X_ES'], shade=True, label = "419X")

# %%
mean_m_wt_rmsf = rmsf_gmx_WT.loc[:,"AVG_WT_ES"].mean(0)
mean_m_c391r_rmsf = rmsf_gmx_C391R.loc[:,"AVG_C391R_ES"].mean(0)
mean_m_419X_rmsf = rmsf_gmx_419X.loc[:,"AVG_419X_ES"].mean(0)
std_wt_rmsf = rmsf_gmx_WT.loc[:,["R1_WT_ES", "R2_WT_ES", "R3_WT_ES"]].std(1)
std_c391r_rmsf = rmsf_gmx_C391R.loc[:,["R1_C391R_ES", "R2_C391R_ES", "R3_C391R_ES"]].std(1)
std_419x_rmsf = rmsf_gmx_419X.loc[:,["R1_419X_ES", "R2_419X_ES", "R3_419X_ES"]].std(1)
meand_std_wt_rmsf = std_wt_rmsf.mean()
meand_std_c391r_rmsf = std_c391r_rmsf.mean()
meand_std_419x_rmsf = std_419x_rmsf.mean()
print("WT Avergae RMSD: ", mean_m_wt_rmsf, "±", meand_std_wt_rmsf)
print("C391R Avergae RMSD: ", mean_m_c391r_rmsf, "±", meand_std_c391r_rmsf)
print("419X Avergae RMSD: ", mean_m_419X_rmsf, "±", meand_std_419x_rmsf)
# Out:
# WT Avergae RMSD:  0.11638110816386679 ± 0.013361472766112808
# C391R Avergae RMSD:  0.12383968253968254 ± 0.022724819694832376
# 419X Avergae RMSD:  0.14292131147540982 ± 0.029687712247151245

# %% [markdown]
# ## Protein SASA

# %%
sasa_gmx_WT_c391r_419x = pd.read_csv('../Data/sasa_WT_C391R_419X.csv', index_col= 'Time (ns)')
sasa_gmx_WT_c391r_419x
# Out:
#              R1_WT    R2_WT    R3_WT      AVG_WT  R1_C391R  R2_C391R  \
# Time (ns)
# 0.000000   199.702  199.736  200.668  200.035333   194.968   200.148
# 0.002000   199.751  203.537  200.737  201.341667   197.608   200.952
# 0.004000   196.695  203.013  200.527  200.078333   200.097   200.731
# 0.006000   197.895  202.232  202.091  200.739333   198.383   200.972
# 0.008000   198.849  202.621  200.230  200.566667   196.006   200.128
# ...            ...      ...      ...         ...       ...       ...
# 49.992001  203.821  203.898  201.868  203.195667   200.532   197.974
# 49.994003  202.577  201.385  203.384  202.448667   197.660   197.604
# 49.996002  203.921  206.572  203.524  204.672333   197.885   198.532
# 49.998001  201.576  201.065  203.216  201.952333   197.817   196.900
# 50.000004  201.947  202.390  205.385  203.240667   199.189   195.009
#
#            R3_C391R   AVG_C391R  R1_419X  R2_419X  R3_419X    AVG_419X
# Time (ns)
# ...

# %%
fig21, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
sasa_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = '', ylabel = 'SASA (nm^2)')#, title = 'WT')
ax1.set_xlim([0, 50])
ax1.set_ylim([180, 220])
ax1.legend(loc='upper right')
sasa_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = '')#, title = 'C391R'), ylabel = 'SASA (nm^2)')
ax2.set_xlim([0, 50])
ax2.set_ylim([180, 220])
ax2.legend(loc='upper right')
sasa_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = '')#, title = '419X'), ylabel = 'SASA (nm^2)')
ax3.set_xlim([0, 50])
ax3.set_ylim([180, 220])
ax3.legend(loc='upper right')

# %%
fig22, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
sasa_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = '', ylabel = 'SASA (nm^2)')
ax1.set_xlim([0, 50])
ax1.set_ylim([190, 210])
ax2.set(xlabel = '', ylabel = 'Función de densidad de probabilidad')
p4=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_WT'], shade=True, label = "WT")
p4=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_C391R'], shade=True, label = "C391R")
p4=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_419X'], shade=True, label = "419X")

# %%
mean_m_wt_sasa = sasa_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_sasa = sasa_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_sasa = sasa_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_sasa = sasa_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_sasa = sasa_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_sasa = sasa_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_sasa = std_wt_sasa.mean()
meand_std_c391r_sasa = std_c391r_sasa.mean()
meand_std_419x_sasa = std_419x_sasa.mean()
print("WT Avergae SASA complete: ", mean_m_wt_sasa, "±", meand_std_wt_sasa)
print("C391R Avergae SASA complete: ", mean_m_c391r_sasa, "±", meand_std_c391r_sasa)
print("419X Avergae SASA complete: ", mean_m_419X_sasa, "±", meand_std_419x_sasa)
# Out:
# WT Avergae SASA complete:  198.938260282922 ± 2.9264491002818636
# C391R Avergae SASA complete:  198.81497676092954 ± 3.5935162122854534
# 419X Avergae SASA complete:  199.9874594749543 ± 3.48115836614898

# %%
fig22, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
temp_30ns = sasa_gmx_WT_c391r_419x[['AVG_WT', 'AVG_C391R', 'AVG_419X']].iloc[10000:]
temp_30ns.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ps)', ylabel = 'SASA (nm^2)')
ax1.set_xlim([20, 50])
ax1.set_ylim([190, 210])
ax2.set(xlabel = 'SASA (nm^2)', ylabel = 'Función de densidad de probabilidad')
p2=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:], shade=True, label = "WT")
p2=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:], shade=True, label = "C391R")
p2=sns.kdeplot(sasa_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:], shade=True, label = "419X")

# %%
mean_m_wt_sasa_20 = sasa_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:].mean(0)
mean_m_c391r_sasa_20 = sasa_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:].mean(0)
mean_m_419X_sasa_20 = sasa_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:].mean(0)
std_wt_sasa_20 = sasa_gmx_WT_c391r_419x[['R1_WT','R2_WT', 'R3_WT']].iloc[10000:].std(1)
std_c391r_sasa_20 = sasa_gmx_WT_c391r_419x[['R1_C391R', 'R2_C391R', 'R3_C391R']].iloc[10000:].std(1)
std_419X_sasa_20 = sasa_gmx_WT_c391r_419x[["R1_419X", "R2_419X", "R3_419X"]].iloc[10000:].std(1)
meand_std_wt_sasa_20 = std_wt_sasa_20.mean()
meand_std_c391r_sasa_20 = std_c391r_sasa_20.mean()
meand_std_419X_sasa_20 = std_419X_sasa_20.mean()
print("WT Average SASA 30ns: ", mean_m_wt_sasa_20, "±", meand_std_wt_sasa_20)
print("C391R Avergae SASA 30 ns: ", mean_m_c391r_sasa_20, "±", meand_std_c391r_sasa_20)
print("419X Avergae SASA 30ns: ", mean_m_419X_sasa_20, "±", meand_std_419X_sasa_20)
# Out:
# WT Average SASA 30ns:  199.4328695198098 ± 3.1352236642879325
# C391R Avergae SASA 30 ns:  198.44820223096238 ± 3.890093169841697
# 419X Avergae SASA 30ns:  199.53079321378573 ± 3.6381371385942103

# %% [markdown]
# # Structural Analysis

# %% [markdown]
# ## Hydrogen Bonds

# %%
hbonds_gmx_WT_c391r_419x = pd.read_csv('../Data/hbonds_WT_C391R_419X.csv', index_col= 'Time (ns)')
hbonds_gmx_WT_c391r_419x
# Out:
#            R1_WT  R2_WT  R3_WT  AVG_WT  R1_C391R  R2_C391R  R3_C391R  \
# Time (ns)
# 0.000000     758    773    784     772       749       763       764
# 0.002000     779    773    798     783       759       777       774
# 0.004000     782    770    792     781       765       758       782
# 0.006000     756    779    759     765       779       772       774
# 0.008000     759    764    774     766       787       771       782
# ...          ...    ...    ...     ...       ...       ...       ...
# 49.992001    802    789    800     797       788       799       808
# 49.994003    785    806    789     793       793       785       785
# 49.996002    803    802    830     812       791       810       789
# 49.998001    800    801    801     801       815       789       798
# 50.000004    799    811    803     804       786       766       790
#
#            AVG_C391R  R1_419X  R2_419X  R3_419X  AVG_419X
# Time (ns)
# ...

# %%
fig23, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3, figsize=(18, 6))
hbonds_gmx_WT_c391r_419x.plot(y = ['R1_WT', 'R2_WT', 'R3_WT'], ax = ax1)
ax1.set(xlabel = 'Tiempo (ps)', ylabel = 'Número de enlaces H')#, title = 'WT')
ax1.set_xlim([0, 50])
ax1.set_ylim([700, 900])
ax1.legend(loc='upper right')
hbonds_gmx_WT_c391r_419x.plot(y = ['R1_C391R', 'R2_C391R', 'R3_C391R'], ax = ax2)
ax2.set(xlabel = 'Tiempo (ps)' )#, ylabel = 'Número de enlaces H', title = 'C391R')
ax2.set_xlim([0, 50])
ax2.set_ylim([700, 900])
ax2.legend(loc='upper right')
hbonds_gmx_WT_c391r_419x.plot( y = ['R1_419X', 'R2_419X', 'R3_419X'], ax = ax3)
ax3.set(xlabel = 'Tiempo (ps)')#, ylabel = 'Número de enlaces H', title = '419X')
ax3.set_xlim([0, 50])
ax3.set_ylim([700, 900])
ax3.legend(loc='upper right')

# %%
fig23, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
hbonds_gmx_WT_c391r_419x.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ps)', ylabel = 'Número de enlaces H')
ax1.set_xlim([0, 5000])
ax1.set_ylim([720, 840])
ax2.set(xlabel = 'Número de enlaces H', ylabel = 'Función de densidad de probabilidad')
p5=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_WT'], shade=True,label = "WT")
p5=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_C391R'], shade=True, label = "C391R")
p5=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_419X'], shade=True, label = "419X")

# %%
mean_m_wt_hb = hbonds_gmx_WT_c391r_419x.loc[:,"AVG_WT"].mean(0)
mean_m_c391r_hb = hbonds_gmx_WT_c391r_419x.loc[:,"AVG_C391R"].mean(0)
mean_m_419X_hb = hbonds_gmx_WT_c391r_419x.loc[:,"AVG_419X"].mean(0)
std_wt_hb = hbonds_gmx_WT_c391r_419x.loc[:,["R1_WT", "R2_WT", "R3_WT"]].std(1)
std_c391r_hb = hbonds_gmx_WT_c391r_419x.loc[:,["R1_C391R", "R2_C391R", "R3_C391R"]].std(1)
std_419x_hb = hbonds_gmx_WT_c391r_419x.loc[:,["R1_419X", "R2_419X", "R3_419X"]].std(1)
meand_std_wt_hb = std_wt_hb.mean()
meand_std_c391r_hb = std_c391r_hb.mean()
meand_std_419x_hb = std_419x_hb.mean()
print("WT Avergae Hydrogen bonds complete: ", mean_m_wt_hb, "±", meand_std_wt_hb)
print("C391R Avergae Hydrogen bonds complete: ", mean_m_c391r_hb, "±", meand_std_c391r_hb)
print("419X Avergae Hydrogen bonds complete: ", mean_m_419X_hb, "±", meand_std_419x_hb)
# Out:
# WT Avergae Hydrogen bonds complete:  793.7785688572457 ± 18.491312625875537
# C391R Avergae Hydrogen bonds complete:  791.963721451142 ± 16.763737795266117
# 419X Avergae Hydrogen bonds complete:  794.7479700811967 ± 14.945344109330414

# %%
fig35, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 6))
temp_30ns = hbonds_gmx_WT_c391r_419x[['AVG_WT', 'AVG_C391R', 'AVG_419X']].iloc[10000:]
temp_30ns.plot(y = ['AVG_WT', 'AVG_C391R', 'AVG_419X'], ax = ax1, label = ["WT", "C391R", "419X"])
ax1.set(xlabel = 'Tiempo (ps)', ylabel = 'Número de enlaces H')
ax1.set_xlim([20000, 50000])
ax1.set_ylim([720, 850])
ax2.set(xlabel = 'Número de enlaces H', ylabel = 'Función de densidad de probabilidad')
p2=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:], shade=True, label = "WT")
p2=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:], shade=True, label = "C391R")
p2=sns.kdeplot(hbonds_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:], shade=True, label = "419X")

# %%
mean_m_wt_hb_20 = hbonds_gmx_WT_c391r_419x['AVG_WT'].iloc[10000:].mean(0)
mean_m_c391r_hb_20 = hbonds_gmx_WT_c391r_419x['AVG_C391R'].iloc[10000:].mean(0)
mean_m_419X_hb_20 = hbonds_gmx_WT_c391r_419x['AVG_419X'].iloc[10000:].mean(0)
std_wt_hb_20 = hbonds_gmx_WT_c391r_419x[['R1_WT','R2_WT', 'R3_WT']].iloc[10000:].std(1)
std_c391r_hb_20 = hbonds_gmx_WT_c391r_419x[['R1_C391R', 'R2_C391R', 'R3_C391R']].iloc[10000:].std(1)
std_419X_hb_20 = hbonds_gmx_WT_c391r_419x[["R1_419X", "R2_419X", "R3_419X"]].iloc[10000:].std(1)
meand_std_wt_hb_20 = std_wt_hb_20.mean()
meand_std_c391r_hb_20 = std_c391r_hb_20.mean()
meand_std_419X_hb_20 = std_419X_hb_20.mean()
print("WT Average Hydrogen bonds 30ns: ", mean_m_wt_hb_20, "±", meand_std_wt_hb_20)
print("C391R Avergae Hydrogen bonds 30ns: ", mean_m_c391r_hb_20, "±", meand_std_c391r_hb_20)
print("419X Avergae Hydrogen bonds 30ns: ", mean_m_419X_hb_20, "±", meand_std_419X_hb_20)
# Out:
# WT Average Hydrogen bonds 30ns:  795.0386640890607 ± 20.627879876486478
# C391R Avergae Hydrogen bonds 30ns:  793.5008332777815 ± 17.607829537627293
# 419X Avergae Hydrogen bonds 30ns:  793.4435037664156 ± 14.522228029663397

# %% [markdown]
# ## Secondary Structure

# %% [markdown]
# # Analysis of time-averaged properties

# %% [markdown]
# ## 2D RMSD
